# %%
DNAphosTau='...'

# %%
print(DNAphosTau)
# Out:
# ...

# %%
print(len(DNAphosTau))
# Out:
# 17111

# %%
DNAphosTau[::-1]
# Out:
# '...'

# %%
from Bio.Seq import Seq

# %%
DNAphosTau=Seq('...')

# %%
DNAphosTau.transcribe()
# Out:
# Seq('UAGUAAGUGUAAGAAGGGGUGGAAAUACCCGCAUCCUGGUAUCUACCUUCCUCG...AAA')

# %%
print(DNAphosTau.transcribe())
# Out:
# ...

# %%
messenger_rna=Seq('...')

# %%
messenger_rna.translate()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/Bio/Seq.py:2334: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   warnings.warn(
# Seq('**V*EGVEIPASWYLPSSSSQQ*QL*TNHKNSLGVEIPLSFCVDVESKKCQKSF...*AQ')
